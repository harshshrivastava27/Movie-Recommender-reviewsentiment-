# %%
import pandas as pd
import numpy as np

# %%
credits=pd.read_csv('/content/drive/MyDrive/movierecommender/credits.csv')

# %%
credits
# Out:
#                                                                                   cast  ...      id
# 0      [{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a3684...  ...     862
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', 'credit_id': '52fe44bfc3a36847f...  ...    8844
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'credit_id': '52fe466a9251416c75...  ...   15602
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah' Jackson", 'credit_id': '52fe...  ...   31357
# 4      [{'cast_id': 1, 'character': 'George Banks', 'credit_id': '52fe44959251416c7...  ...   11862
# ...                                                                                ...  ...     ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': '5894a909925141427e0079a5', 'g...  ...  439050
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela', 'credit_id': '52fe4af1c3a36...  ...  111109
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'credit_id': '52fe4776c3a368484e0...  ...   67758
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': '52fe4ea59251416c7515d7d5', 'g...  ...  227506
# 45475                                                                               []  ...  461257
#
# [45476 rows x 3 columns]

# %%
meta=pd.read_csv('/content/drive/MyDrive/movierecommender/movies_metadata.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
meta.head(10)
# Out:
#    adult  ... vote_count
# 0  False  ...     5415.0
# 1  False  ...     2413.0
# 2  False  ...       92.0
# 3  False  ...       34.0
# 4  False  ...      173.0
# 5  False  ...     1886.0
# 6  False  ...      141.0
# 7  False  ...       45.0
# 8  False  ...      174.0
# 9  False  ...     1194.0
#
# [10 rows x 24 columns]

# %%
meta['release_date']=pd.to_datetime(meta['release_date'], errors='coerce')

# %%
meta['year']=meta['release_date'].dt.year

# %%
meta['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
new_meta=meta.loc[meta.year==2017,['genres','id','title','year']]

# %%
new_meta
# Out:
#                                                                                 genres  ...    year
# 26560  [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': 14, '...  ...  2017.0
# 26561  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, '...  ...  2017.0
# 26565  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, '...  ...  2017.0
# 26566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, '...  ...  2017.0
# 30536  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'name': 'Action'}, {'id': 12, 'na...  ...  2017.0
# ...                                                                                ...  ...     ...
# 45398                 [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]  ...  2017.0
# 45417  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}, {'id': 28, 'name...  ...  2017.0
# 45437  [{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id': 10...  ...  2017.0
# 45453  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name'...  ...  2017.0
# 45465                                                                               []  ...  2017.0
#
# [532 rows x 4 columns]

# %%
new_meta['id']=new_meta['id'].astype(int)

# %%
data=pd.merge(new_meta,credits, on='id')

# %%
pd.set_option('display.max_colwidth',80)
data
# Out:
#                                                                               genres  ...                                                                             crew
# 0    [{'id': 12, 'name': 'Adventure'}, {'id': 28, 'name': 'Action'}, {'id': 14, '...  ...  [{'credit_id': '52fe4c9cc3a36847f8236a65', 'department': 'Production', 'gend...
# 1    [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, '...  ...  [{'credit_id': '55ef66dbc3a3686f1700a52d', 'department': 'Production', 'gend...
# 2    [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, '...  ...  [{'credit_id': '56a93fa4c3a36872db001e7a', 'department': 'Writing', 'gender'...
# 3    [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 35, '...  ...  [{'credit_id': '59171547925141583c0315a6', 'department': 'Sound', 'gender': ...
# 4    [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'name': 'Action'}, {'id': 12, 'na...  ...  [{'credit_id': '5431de49c3a36825d300007e', 'department': 'Directing', 'gende...
# ..                                                                               ...  ...                                                                              ...
# 526                 [{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]  ...  [{'credit_id': '597e22f69251415d7801c74a', 'department': 'Directing', 'gende...
# 527  [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}, {'id': 28, 'name...  ...  [{'credit_id': '593ba0c29251410593009be3', 'department': 'Writing', 'gender'...
# 528  [{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id': 10...  ...  [{'credit_id': '5981a15c92514151e0011b51', 'department': 'Sound', 'gender': ...
# 529  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name': 'Drama'}, {'id': 53, 'name'...  ...  [{'credit_id': '58ee55bbc3a3683df500bd0f', 'department': 'Sound', 'gender': ...
# 530                                                                               []  ...  [{'credit_id': '593e676c92514105b702e68e', 'department': 'Directing', 'gende...
#
# [531 rows x 6 columns]

# %%
import ast
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list']=data['genres'].map(lambda x: makegenrelist(x))

# %%
data['genres_list']
# Out:
# 0      Adventure Action Fantasy Comedy
# 1      Action Adventure Fantasy Sci-Fi
# 2      Action Adventure Fantasy Sci-Fi
# 3       Action Adventure Comedy Sci-Fi
# 4             Fantasy Action Adventure
#                     ...
# 526                     Romance Comedy
# 527         Crime Comedy Action Family
# 528    Family Animation Romance Comedy
# 529               Crime Drama Thriller
# 530                                NaN
# Name: genres_list, Length: 531, dtype: object

# %%
def get_actor1(x):
    casts=[]
    for i in x:
      casts.append(i.get('name'))
    if casts==[]:
      return np.NaN
    else:
      return (casts[0])

# %%
data['actor_1_name']=data['cast'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    casts=[]
    for i in x:
      casts.append(i.get('name'))
    if casts==[] or len(casts)<=1:
      return np.NaN
    else:
       return (casts[1])

# %%
data['actor_2_name']=data['cast'].map(lambda x: get_actor2(x))

# %%
data['actor_2_name']
# Out:
# 0       Javier Bardem
# 1        Henry Cavill
# 2      Tom Hiddleston
# 3         Zoe Saldana
# 4        William Hurt
#             ...
# 526     Rosa Honkonen
# 527     Wallace Shawn
# 528               NaN
# 529         Sajal Ali
# 530               NaN
# Name: actor_2_name, Length: 531, dtype: object

# %%
def get_actor3(x):
    casts=[]
    for i in x:
      casts.append(i.get('name'))
    if casts==[] or len(casts)<=2:
      return np.NaN
    else:
       return (casts[2])

# %%
data['actor_3_name']=data['cast'].map(lambda x: get_actor3(x))

# %%
data['actor_3_name']
# Out:
# 0        Geoffrey Rush
# 1            Gal Gadot
# 2       Cate Blanchett
# 3        Dave Bautista
# 4      Benjamin Walker
#             ...
# 526     Tiitus Rantala
# 527        Gina Holden
# 528                NaN
# 529     Akshaye Khanna
# 530                NaN
# Name: actor_3_name, Length: 531, dtype: object

# %%
def get_directors(x):
    dt=[]
    st=" "
    for i in x:
      if i.get('job')=='Director':
        dt.append(i.get('name'))
    if dt == []:
      return np.NaN
    else:
       return (st.join(dt))

# %%
data['director_name']=data['crew'].map(lambda x: get_directors(x))

# %%
data['director_name']
# Out:
# 0      Joachim Rønning Espen Sandberg
# 1                         Zack Snyder
# 2                       Taika Waititi
# 3                          James Gunn
# 4                       Sean McNamara
#                     ...
# 526                  Hannaleena Hauru
# 527             Jonathan A. Rosenbaum
# 528          Beth David Esteban Bravo
# 529                      Ravi Udyawar
# 530                     Daisy Asquith
# Name: director_name, Length: 531, dtype: object

# %%
data.columns
# Out:
# Index(['genres', 'id', 'title', 'year', 'cast', 'crew', 'genres_list',
#        'actor_1_name', 'actor_2_name', 'actor_3_name', 'director_name'],
#       dtype='object')

# %%
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]

# %%
movie
# Out:
#                       director_name  ...                                             title
# 0    Joachim Rønning Espen Sandberg  ...  Pirates of the Caribbean: Dead Men Tell No Tales
# 1                       Zack Snyder  ...                                    Justice League
# 2                     Taika Waititi  ...                                    Thor: Ragnarok
# 3                        James Gunn  ...                    Guardians of the Galaxy Vol. 2
# 4                     Sean McNamara  ...                               The King's Daughter
# ..                              ...  ...                                               ...
# 526                Hannaleena Hauru  ...                  Thick Lashes of Lauri Mäntyvaara
# 527           Jonathan A. Rosenbaum  ...                       Cop and a Half: New Recruit
# 528        Beth David Esteban Bravo  ...                                    In a Heartbeat
# 529                    Ravi Udyawar  ...                                               Mom
# 530                   Daisy Asquith  ...                                          Queerama
#
# [531 rows x 6 columns]

# %%
movie.isna().sum()
# Out:
# director_name     4
# actor_1_name     22
# actor_2_name     55
# actor_3_name     70
# genres_list       7
# title             0
# dtype: int64

# %%
movie=movie.dropna(how='any')

# %%
movie=movie.rename(columns={'genres_list':'genres'})
#didn't get renamed use genres_list
movie=movie.rename(columns={'title':'movie_title'})

# %%
movie
# Out:
#                       director_name  ...                                       movie_title
# 0    Joachim Rønning Espen Sandberg  ...  Pirates of the Caribbean: Dead Men Tell No Tales
# 1                       Zack Snyder  ...                                    Justice League
# 2                     Taika Waititi  ...                                    Thor: Ragnarok
# 3                        James Gunn  ...                    Guardians of the Galaxy Vol. 2
# 4                     Sean McNamara  ...                               The King's Daughter
# ..                              ...  ...                                               ...
# 524                     Jim Strouse  ...                      The Incredible Jessica James
# 525                     Farhad Mann  ...                                 Can't Buy My Love
# 526                Hannaleena Hauru  ...                  Thick Lashes of Lauri Mäntyvaara
# 527           Jonathan A. Rosenbaum  ...                       Cop and a Half: New Recruit
# 529                    Ravi Udyawar  ...                                               Mom
#
# [458 rows x 6 columns]

# %%
old=pd.read_csv('/content/drive/MyDrive/movierecommender/data.csv')

# %%
old
# Out:
#           director_name  ...                                             movie_title
# 0         James Cameron  ...                                                  avatar
# 1        Gore Verbinski  ...                pirates of the caribbean: at world's end
# 2            Sam Mendes  ...                                                 spectre
# 3     Christopher Nolan  ...                                   the dark knight rises
# 4           Doug Walker  ...  star wars: episode vii - the force awakens
# ...                 ...  ...                                                     ...
# 5038        Scott Smith  ...                                 signed sealed delivered
# 5039            unknown  ...                               the following
# 5040   Benjamin Roberds  ...                                    a plague so pleasant
# 5041        Daniel Hsia  ...                                        shanghai calling
# 5042           Jon Gunn  ...                                       my date with drew
#
# [5043 rows x 6 columns]

# %%
old['comb'] = old['actor_1_name'] + ' ' + old['actor_2_name'] + ' '+ old['actor_3_name'] + ' '+ old['director_name'] +' ' + old['genres']

# %%
old
# Out:
#           director_name  ...                                                                             comb
# 0         James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James Cameron Action Adventure Fantas...
# 1        Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore Verbinski Action Adventure Fan...
# 2            Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman Sam Mendes Action Adventure Th...
# 3     Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt Christopher Nolan Action Thriller
# 4           Doug Walker  ...                           Doug Walker Rob Walker unknown Doug Walker Documentary
# ...                 ...  ...                                                                              ...
# 5038        Scott Smith  ...                  Eric Mabius Daphne Zuniga Crystal Lowe Scott Smith Comedy Drama
# 5039            unknown  ...     Natalie Zea Valorie Curry Sam Underwood unknown Crime Drama Mystery Thriller
# 5040   Benjamin Roberds  ...  Eva Boehnke Maxwell Moody David Chandler Benjamin Roberds Drama Horror Thriller
# 5041        Daniel Hsia  ...             Alan Ruck Daniel Henney Eliza Coupe Daniel Hsia Comedy Drama Romance
# 5042           Jon Gunn  ...                       John August Brian Herzlinger Jon Gunn Jon Gunn Documentary
#
# [5043 rows x 7 columns]

# %%
new = old.append(movie)

# %%
new
# Out:
#              director_name  ...                                                                             comb
# 0            James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James Cameron Action Adventure Fantas...
# 1           Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore Verbinski Action Adventure Fan...
# 2               Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman Sam Mendes Action Adventure Th...
# 3        Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt Christopher Nolan Action Thriller
# 4              Doug Walker  ...                           Doug Walker Rob Walker unknown Doug Walker Documentary
# ..                     ...  ...                                                                              ...
# 524            Jim Strouse  ...         Jessica Williams Chris O'Dowd Keith Stanfield Jim Strouse Romance Comedy
# 525            Farhad Mann  ...       Adelaide Kane Benjamin Hollingsworth Jean Louisa Kelly Farhad Mann Romance
# 526       Hannaleena Hauru  ...      Inka Haapamäki Rosa Honkonen Tiitus Rantala Hannaleena Hauru Romance Comedy
# 527  Jonathan A. Rosenbaum  ...  Lou Diamond Phillips Wallace Shawn Gina Holden Jonathan A. Rosenbaum Crime C...
# 529           Ravi Udyawar  ...        Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi Udyawar Crime Drama Thriller
#
# [5501 rows x 7 columns]

# %%
new.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)

# %%
new
# Out:
#              director_name  ...                                                                             comb
# 0            James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James Cameron Action Adventure Fantas...
# 1           Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore Verbinski Action Adventure Fan...
# 2               Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman Sam Mendes Action Adventure Th...
# 3        Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt Christopher Nolan Action Thriller
# 4              Doug Walker  ...                           Doug Walker Rob Walker unknown Doug Walker Documentary
# ..                     ...  ...                                                                              ...
# 524            Jim Strouse  ...         Jessica Williams Chris O'Dowd Keith Stanfield Jim Strouse Romance Comedy
# 525            Farhad Mann  ...       Adelaide Kane Benjamin Hollingsworth Jean Louisa Kelly Farhad Mann Romance
# 526       Hannaleena Hauru  ...      Inka Haapamäki Rosa Honkonen Tiitus Rantala Hannaleena Hauru Romance Comedy
# 527  Jonathan A. Rosenbaum  ...  Lou Diamond Phillips Wallace Shawn Gina Holden Jonathan A. Rosenbaum Crime C...
# 529           Ravi Udyawar  ...        Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi Udyawar Crime Drama Thriller
#
# [5364 rows x 7 columns]

# %%
new.to_csv('new_data.csv',index=False)
