# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/content/drive/MyDrive/movierecommender/movie_metadata.csv')

# %%
data.head(10)
# Out:
#    color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0  Color      James Cameron  ...          1.78                 33000
# 1  Color     Gore Verbinski  ...          2.35                     0
# 2  Color         Sam Mendes  ...          2.35                 85000
# 3  Color  Christopher Nolan  ...          2.35                164000
# 4    NaN        Doug Walker  ...           NaN                     0
# 5  Color     Andrew Stanton  ...          2.35                 24000
# 6  Color          Sam Raimi  ...          2.35                     0
# 7  Color       Nathan Greno  ...          1.85                 29000
# 8  Color        Joss Whedon  ...          2.35                118000
# 9  Color        David Yates  ...          2.35                 10000
#
# [10 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
data.title_year.value_counts(dropna=False).sort_index().plot(kind='barh',figsize=(14,15))
plt.show()

# %%
(data.movie_title== 'Avatar\xa0').sum()
# Out:
# 1

# %%
data.loc[data.movie_title=='Avatar\xa0',['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
# Out:
#    director_name actor_1_name  ...                           genres movie_title
# 0  James Cameron  CCH Pounder  ...  Action|Adventure|Fantasy|Sci-Fi     Avatar
#
# [1 rows x 6 columns]

# %%
data = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
data.head(10)
# Out:
#        director_name  ...                                        movie_title
# 0      James Cameron  ...                                            Avatar
# 1     Gore Verbinski  ...          Pirates of the Caribbean: At World's End
# 2         Sam Mendes  ...                                           Spectre
# 3  Christopher Nolan  ...                             The Dark Knight Rises
# 4        Doug Walker  ...  Star Wars: Episode VII - The Force Awakens    ...
# 5     Andrew Stanton  ...                                       John Carter
# 6          Sam Raimi  ...                                      Spider-Man 3
# 7       Nathan Greno  ...                                           Tangled
# 8        Joss Whedon  ...                           Avengers: Age of Ultron
# 9        David Yates  ...            Harry Potter and the Half-Blood Prince
#
# [10 rows x 6 columns]

# %%
data['actor_1_name']=data['actor_1_name'].replace(np.nan,'unknown')
data['actor_2_name']=data['actor_2_name'].replace(np.nan,'unknown')
data['actor_3_name']=data['actor_3_name'].replace(np.nan,'unknown')
data['director_name']=data['director_name'].replace(np.nan,'unknown')

# %%
data['genres'] = data['genres'].str.replace('|', ' ')

# %%
data.head(2)
# Out:
#     director_name  ...                                movie_title
# 0   James Cameron  ...                                    Avatar
# 1  Gore Verbinski  ...  Pirates of the Caribbean: At World's End
#
# [2 rows x 6 columns]

# %%
data['movie_title']=data['movie_title'].str.lower()

# %%
data['movie_title'][1]
# Out:
# "pirates of the caribbean: at world's end\xa0"

# %%
data['movie_title']=data['movie_title'].apply(lambda x : x[:-1])

# %%
data['movie_title'][1]
# Out:
# "pirates of the caribbean: at world's end"

# %%
data.to_csv('data.csv',index=False)

# %%
data.head()
# Out:
#        director_name  ...                                        movie_title
# 0      James Cameron  ...                                             avatar
# 1     Gore Verbinski  ...           pirates of the caribbean: at world's end
# 2         Sam Mendes  ...                                            spectre
# 3  Christopher Nolan  ...                              the dark knight rises
# 4        Doug Walker  ...  star wars: episode vii - the force awakens    ...
#
# [5 rows x 6 columns]
